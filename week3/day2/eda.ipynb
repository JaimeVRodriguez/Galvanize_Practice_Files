# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Datasets
# Dataset one
data_one_x = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
data_one_y = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68])
df_one = pd.DataFrame(data=[data_one_x, data_one_y], index=['x', 'y'])
df_one = df_one.T
# Dataset two
data_two_x = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
data_two_y = np.array([9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])
df_two = pd.DataFrame(data=[data_two_x, data_two_y], index=['x', 'y'])
df_two = df_two.T
# Dataset three
data_three_x = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
data_three_y = np.array([7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])
df_three = pd.DataFrame(data=[data_three_x, data_three_y], index=['x', 'y'])
df_three = df_three.T
# Dataset four
data_four_x = np.array([8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8])
data_four_y = np.array([6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89])
df_four = pd.DataFrame(data=[data_four_x, data_four_y], index=['x', 'y'])
df_four = df_four.T

# %%
df1_mean = df_one.mean()
df2_mean = df_two.mean()
df3_mean = df_three.mean()
df4_mean = df_four.mean()

print("DF1 Mean")
print(df1_mean)
print("DF2 Mean")
print(df2_mean)
print("DF3 Mean")
print(df3_mean)
print("DF4 Mean")
print(df4_mean)
print()
print("DF1 STD")
print(df_one.std())
print("DF2 STD")
print(df_two.std())
print("DF3 STD")
print(df_three.std())
print("DF4 STD")
print(df_four.std())
print()
print(df_one.corr())
# Out:
# DF1 Mean
# x    9.000000
# y    7.500909
# dtype: float64
# DF2 Mean
# x    9.000000
# y    7.500909
# dtype: float64
# DF3 Mean
# x    9.0
# y    7.5
# dtype: float64
# DF4 Mean
# x    9.000000
# y    7.500909
# dtype: float64
#
# DF1 STD
# x    3.316625
# y    2.031568
# dtype: float64
# DF2 STD
# x    3.316625
# y    2.031657
# dtype: float64
# DF3 STD
# x    3.316625
# y    2.030424
# dtype: float64
# DF4 STD
# x    3.316625
# y    2.030579
# dtype: float64
#
#           x         y
# x  1.000000  0.816421
# y  0.816421  1.000000

# %%
fig, ax = plt.subplots(2, 2)

m1, b1 = np.polyfit(df_one['x'], df_one['y'], 1)
m2, b2 = np.polyfit(df_two['x'], df_two['y'], 1)
m3, b3 = np.polyfit(df_three['x'], df_three['y'], 1)
m4, b4 = np.polyfit(df_four['x'], df_four['y'], 1)

ax[0, 0].scatter(df_one['x'], df_one['y'])
ax[0, 0].plot(df_one['x'], m1*df_one['x']+b1, color='red')

ax[0, 1].scatter(df_two['x'], df_two['y'])
ax[0, 1].plot(df_two['x'], m2*df_two['x']+b2, color='red')

ax[1, 0].scatter(df_three['x'], df_three['y'])
ax[1, 0].plot(df_three['x'], m3*df_three['x']+b3, color='red')

ax[1, 1].scatter(df_four['x'], df_four['y'])
ax[1, 1].plot(df_four['x'], m4*df_four['x']+b4, color='red')
